# %%
import pandas as pd

# %%
# import data
df = pd.read_csv('/Users/agneslu/Desktop/neighborhood-data/data-new/housing-age/ACSDP5Y2023.DP04-Data.csv')
df.head(3)
# Out:
#                  GEO_ID                                               NAME  \
# 0             Geography                               Geographic Area Name
# 1  1400000US06075010101  Census Tract 101.01; San Francisco County; Cal...
# 2  1400000US06075010102  Census Tract 101.02; San Francisco County; Cal...
#
#                                          DP04_0001E  \
# 0  Estimate!!HOUSING OCCUPANCY!!Total housing units
# 1                                              1407
# 2                                              1046
#
#                                           DP04_0001M  \
# 0  Margin of Error!!HOUSING OCCUPANCY!!Total hous...
# 1                                                198
# 2                                                202
#
#                                           DP04_0002E  \
# 0  Estimate!!HOUSING OCCUPANCY!!Total housing uni...
# 1                                               1212
# 2                                                907
#
# ...

# %%
# drop the first column
df = df.drop(df.columns[0], axis=1)
df.head(3)
# Out:
#                                                 NAME  \
# 0                               Geographic Area Name
# 1  Census Tract 101.01; San Francisco County; Cal...
# 2  Census Tract 101.02; San Francisco County; Cal...
#
#                                          DP04_0001E  \
# 0  Estimate!!HOUSING OCCUPANCY!!Total housing units
# 1                                              1407
# 2                                              1046
#
#                                           DP04_0001M  \
# 0  Margin of Error!!HOUSING OCCUPANCY!!Total hous...
# 1                                                198
# 2                                                202
#
#                                           DP04_0002E  \
# 0  Estimate!!HOUSING OCCUPANCY!!Total housing uni...
# 1                                               1212
# 2                                                907
#
#                                           DP04_0002M  \
# ...

# %%
# change NAME to Area
df = df.rename(columns={'NAME': 'Area'})
df.head(3)
# Out:
#                                                 Area  \
# 0                               Geographic Area Name
# 1  Census Tract 101.01; San Francisco County; Cal...
# 2  Census Tract 101.02; San Francisco County; Cal...
#
#                                          DP04_0001E  \
# 0  Estimate!!HOUSING OCCUPANCY!!Total housing units
# 1                                              1407
# 2                                              1046
#
#                                           DP04_0001M  \
# 0  Margin of Error!!HOUSING OCCUPANCY!!Total hous...
# 1                                                198
# 2                                                202
#
#                                           DP04_0002E  \
# 0  Estimate!!HOUSING OCCUPANCY!!Total housing uni...
# 1                                               1212
# 2                                                907
#
#                                           DP04_0002M  \
# ...

# %%
# drop the margin columns
df = df[df.columns.drop(list(df.filter(regex='M')))]
df.head(3)
# Out:
#                                                 Area  \
# 0                               Geographic Area Name
# 1  Census Tract 101.01; San Francisco County; Cal...
# 2  Census Tract 101.02; San Francisco County; Cal...
#
#                                          DP04_0001E  \
# 0  Estimate!!HOUSING OCCUPANCY!!Total housing units
# 1                                              1407
# 2                                              1046
#
#                                           DP04_0002E  \
# 0  Estimate!!HOUSING OCCUPANCY!!Total housing uni...
# 1                                               1212
# 2                                                907
#
#                                           DP04_0003E  \
# 0  Estimate!!HOUSING OCCUPANCY!!Total housing uni...
# 1                                                195
# 2                                                139
#
#                                           DP04_0004E  \
# ...

# %%
# drop the last column, the header is NaN
df = df.drop(df.columns[-1], axis=1)
df.head(3)
# Out:
#                                                 Area  \
# 0                               Geographic Area Name
# 1  Census Tract 101.01; San Francisco County; Cal...
# 2  Census Tract 101.02; San Francisco County; Cal...
#
#                                          DP04_0001E  \
# 0  Estimate!!HOUSING OCCUPANCY!!Total housing units
# 1                                              1407
# 2                                              1046
#
#                                           DP04_0002E  \
# 0  Estimate!!HOUSING OCCUPANCY!!Total housing uni...
# 1                                               1212
# 2                                                907
#
#                                           DP04_0003E  \
# 0  Estimate!!HOUSING OCCUPANCY!!Total housing uni...
# 1                                                195
# 2                                                139
#
#                                           DP04_0004E  \
# ...

# %%
# rename columns
column_mapping = {}
for i, col in enumerate(df.columns):
    if i < len(df.iloc[0]):  # Make sure we don't go out of bounds
        column_mapping[col] = df.iloc[0, i]

df = df.rename(columns=column_mapping)
df.head(3)
# Out:
#                                 Geographic Area Name  \
# 0                               Geographic Area Name
# 1  Census Tract 101.01; San Francisco County; Cal...
# 2  Census Tract 101.02; San Francisco County; Cal...
#
#    Estimate!!HOUSING OCCUPANCY!!Total housing units  \
# 0  Estimate!!HOUSING OCCUPANCY!!Total housing units
# 1                                              1407
# 2                                              1046
#
#   Estimate!!HOUSING OCCUPANCY!!Total housing units!!Occupied housing units  \
# 0  Estimate!!HOUSING OCCUPANCY!!Total housing uni...
# 1                                               1212
# 2                                                907
#
#   Estimate!!HOUSING OCCUPANCY!!Total housing units!!Vacant housing units  \
# 0  Estimate!!HOUSING OCCUPANCY!!Total housing uni...
# 1                                                195
# 2                                                139
#
# ...

# %%
# remove the first row
df = df.drop(df.index[0])  
df = df.reset_index(drop=True)
df.head(3)
# Out:
#                                 Geographic Area Name  \
# 0  Census Tract 101.01; San Francisco County; Cal...
# 1  Census Tract 101.02; San Francisco County; Cal...
# 2  Census Tract 102.01; San Francisco County; Cal...
#
#   Estimate!!HOUSING OCCUPANCY!!Total housing units  \
# 0                                             1407
# 1                                             1046
# 2                                             1641
#
#   Estimate!!HOUSING OCCUPANCY!!Total housing units!!Occupied housing units  \
# 0                                               1212
# 1                                                907
# 2                                               1375
#
#   Estimate!!HOUSING OCCUPANCY!!Total housing units!!Vacant housing units  \
# 0                                                195
# 1                                                139
# 2                                                266
#
# ...

# %%
# change Geographic Area Name to Area
df = df.rename(columns={'Geographic Area Name': 'Area'})

# %%
# only keep numbers for the area column
df['Area'] = df['Area'].str.replace(r'.*Census Tract\s+', '', regex=True)  # remove everything before tract number
df['Area'] = df['Area'].str.replace(r';.*', '', regex=True)  # remove everything after semicolon
df['Area'] = df['Area'].str.strip()  # remove any extra whitespace
df.head(3)
# Out:
#      Area Estimate!!HOUSING OCCUPANCY!!Total housing units  \
# 0  101.01                                             1407
# 1  101.02                                             1046
# 2  102.01                                             1641
#
#   Estimate!!HOUSING OCCUPANCY!!Total housing units!!Occupied housing units  \
# 0                                               1212
# 1                                                907
# 2                                               1375
#
#   Estimate!!HOUSING OCCUPANCY!!Total housing units!!Vacant housing units  \
# 0                                                195
# 1                                                139
# 2                                                266
#
#   Estimate!!HOUSING OCCUPANCY!!Total housing units!!Homeowner vacancy rate  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
#
# ...

# %%
# only keep the column of Area, and columns with YEAR STRUCTURE BUILT in it
df = df[['Area'] + [col for col in df.columns if 'YEAR STRUCTURE BUILT' in col]]
df.head(3)
# Out:
#      Area Estimate!!YEAR STRUCTURE BUILT!!Total housing units  \
# 0  101.01                                               1407
# 1  101.02                                               1046
# 2  102.01                                               1641
#
#   Estimate!!YEAR STRUCTURE BUILT!!Total housing units!!Built 2020 or later  \
# 0                                                  0
# 1                                                  0
# 2                                                 11
#
#   Estimate!!YEAR STRUCTURE BUILT!!Total housing units!!Built 2010 to 2019  \
# 0                                                 11
# 1                                                 19
# 2                                                 10
#
#   Estimate!!YEAR STRUCTURE BUILT!!Total housing units!!Built 2000 to 2009  \
# 0                                                 83
# 1                                                544
# 2                                                 11
#
# ...

# %%
# get rid of Estimate!!YEAR STRUCTURE BUILT!!Total housing units!! in the column names
df.columns = df.columns.str.replace('Estimate!!YEAR STRUCTURE BUILT!!Total housing units!!', '', regex=True)
df.head(3)
# Out:
#      Area Estimate!!YEAR STRUCTURE BUILT!!Total housing units  \
# 0  101.01                                               1407
# 1  101.02                                               1046
# 2  102.01                                               1641
#
#   Built 2020 or later Built 2010 to 2019 Built 2000 to 2009  \
# 0                   0                 11                 83
# 1                   0                 19                544
# 2                  11                 10                 11
#
#   Built 1990 to 1999 Built 1980 to 1989 Built 1970 to 1979 Built 1960 to 1969  \
# 0                 15                237                306                519
# 1                289                  8                 31                 20
# 2                  0                141                158                 17
#
#   Built 1950 to 1959  ...  \
# 0                 27  ...
# 1                  5  ...
# 2                 68  ...
#
# ...

# %%
# change the second column name to Total
df = df.rename(columns={df.columns[1]: 'Total'})
df.head(3)
# Out:
#      Area Total Built 2020 or later Built 2010 to 2019 Built 2000 to 2009  \
# 0  101.01  1407                   0                 11                 83
# 1  101.02  1046                   0                 19                544
# 2  102.01  1641                  11                 10                 11
#
#   Built 1990 to 1999 Built 1980 to 1989 Built 1970 to 1979 Built 1960 to 1969  \
# 0                 15                237                306                519
# 1                289                  8                 31                 20
# 2                  0                141                158                 17
#
#   Built 1950 to 1959  ...  \
# 0                 27  ...
# 1                  5  ...
# 2                 68  ...
#
#   Percent!!YEAR STRUCTURE BUILT!!Total housing units!!Built 2020 or later  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.7
#
# ...

# %%
# drop columns with Percent!! in it
df = df[df.columns.drop(list(df.filter(regex='Percent!!')))]
df.head(3)
# Out:
#      Area Total Built 2020 or later Built 2010 to 2019 Built 2000 to 2009  \
# 0  101.01  1407                   0                 11                 83
# 1  101.02  1046                   0                 19                544
# 2  102.01  1641                  11                 10                 11
#
#   Built 1990 to 1999 Built 1980 to 1989 Built 1970 to 1979 Built 1960 to 1969  \
# 0                 15                237                306                519
# 1                289                  8                 31                 20
# 2                  0                141                158                 17
#
#   Built 1950 to 1959 Built 1940 to 1949 Built 1939 or earlier
# 0                 27                 92                   117
# 1                  5                 28                   102
# 2                 68                 91                  1134

# %%
# combine a few columns
df['2000 to current'] = df[['Built 2020 or later', 'Built 2010 to 2019', 'Built 2000 to 2009']].apply(pd.to_numeric, errors='coerce').sum(axis=1)
df['1970 to 2000'] = df[['Built 1990 to 1999', 'Built 1980 to 1989', 'Built 1970 to 1979']].apply(pd.to_numeric, errors='coerce').sum(axis=1)
df['1940 to 1970'] = df[['Built 1960 to 1969', 'Built 1950 to 1959', 'Built 1940 to 1949']].apply(pd.to_numeric, errors='coerce').sum(axis=1)
df['Pre-1940'] = df[['Built 1939 or earlier']].apply(pd.to_numeric, errors='coerce').sum(axis=1)
# only keep the columns we need
columns_to_keep = ['Area', 'Total', '2000 to current', '1970 to 2000', '1940 to 1970', 'Pre-1940']
df = df[columns_to_keep]
df.head(3)
# Out:
#      Area Total  2000 to current  1970 to 2000  1940 to 1970  Pre-1940
# 0  101.01  1407               94           558           638       117
# 1  101.02  1046              563           328            53       102
# 2  102.01  1641               32           299           176      1134

# %%
# convert numeric columns to proper data types
numeric_columns = ['Total', '2000 to current', '1970 to 2000', '1940 to 1970', 'Pre-1940']
df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')

# create the dictionary in the format you want
result_dict = {
    '2000 to current': df.set_index('Area')['2000 to current'].to_dict(),
    '1970 to 2000': df.set_index('Area')['1970 to 2000'].to_dict(), 
    '1940 to 1970': df.set_index('Area')['1940 to 1970'].to_dict(),
    'pre-1940': df.set_index('Area')['Pre-1940'].to_dict(),
    'total': df.set_index('Area')['Total'].to_dict()
}

# convert to JSON and save to file
import json

with open('/Users/agneslu/Desktop/neighborhood-data/data-new/housing_age.json', 'w') as f:
    json.dump(result_dict, f, indent=2)

print("JSON file saved as 'housing_age.json'")
# Out:
# JSON file saved as 'housing-age.json'
