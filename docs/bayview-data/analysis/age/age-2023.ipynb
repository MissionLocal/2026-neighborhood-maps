# %%
import pandas as pd

# %%
# import data
df = pd.read_csv('/Users/agneslu/Desktop/neighborhood-data/data-new/age/ACSDP5Y2023.DP05-Data.csv')

# %%
df.head(3)
# Out:
#                  GEO_ID                                               NAME  \
# 0             Geography                               Geographic Area Name
# 1  1400000US06075010101  Census Tract 101.01; San Francisco County; Cal...
# 2  1400000US06075010102  Census Tract 101.02; San Francisco County; Cal...
#
#                                 DP05_0001E  \
# 0  Estimate!!SEX AND AGE!!Total population
# 1                                     2004
# 2                                     1795
#
#                                        DP05_0001M  \
# 0  Margin of Error!!SEX AND AGE!!Total population
# 1                                             297
# 2                                             345
#
#                                       DP05_0002E  \
# 0  Estimate!!SEX AND AGE!!Total population!!Male
# 1                                           1077
# 2                                            786
#
#                                           DP05_0002M  \
# ...

# %%
# drop the first column
df = df.drop(df.columns[0], axis=1)
df.head(3)
# Out:
#                                                 NAME  \
# 0                               Geographic Area Name
# 1  Census Tract 101.01; San Francisco County; Cal...
# 2  Census Tract 101.02; San Francisco County; Cal...
#
#                                 DP05_0001E  \
# 0  Estimate!!SEX AND AGE!!Total population
# 1                                     2004
# 2                                     1795
#
#                                        DP05_0001M  \
# 0  Margin of Error!!SEX AND AGE!!Total population
# 1                                             297
# 2                                             345
#
#                                       DP05_0002E  \
# 0  Estimate!!SEX AND AGE!!Total population!!Male
# 1                                           1077
# 2                                            786
#
#                                           DP05_0002M  \
# 0  Margin of Error!!SEX AND AGE!!Total population...
# 1                                                173
# ...

# %%
# change NAME to Area
df = df.rename(columns={'NAME': 'Area'})
df.head(3)
# Out:
#                                                 Area  \
# 0                               Geographic Area Name
# 1  Census Tract 101.01; San Francisco County; Cal...
# 2  Census Tract 101.02; San Francisco County; Cal...
#
#                                 DP05_0001E  \
# 0  Estimate!!SEX AND AGE!!Total population
# 1                                     2004
# 2                                     1795
#
#                                        DP05_0001M  \
# 0  Margin of Error!!SEX AND AGE!!Total population
# 1                                             297
# 2                                             345
#
#                                       DP05_0002E  \
# 0  Estimate!!SEX AND AGE!!Total population!!Male
# 1                                           1077
# 2                                            786
#
#                                           DP05_0002M  \
# 0  Margin of Error!!SEX AND AGE!!Total population...
# 1                                                173
# ...

# %%
# drop the margin columns
df = df[df.columns.drop(list(df.filter(regex='M')))]
df.head(3)
# Out:
#                                                 Area  \
# 0                               Geographic Area Name
# 1  Census Tract 101.01; San Francisco County; Cal...
# 2  Census Tract 101.02; San Francisco County; Cal...
#
#                                 DP05_0001E  \
# 0  Estimate!!SEX AND AGE!!Total population
# 1                                     2004
# 2                                     1795
#
#                                       DP05_0002E  \
# 0  Estimate!!SEX AND AGE!!Total population!!Male
# 1                                           1077
# 2                                            786
#
#                                         DP05_0003E  \
# 0  Estimate!!SEX AND AGE!!Total population!!Female
# 1                                              927
# 2                                             1009
#
#                                           DP05_0004E  \
# 0  Estimate!!SEX AND AGE!!Total population!!Sex r...
# ...

# %%
# drop the last column, the header is NaN
df = df.drop(df.columns[-1], axis=1)
df.head(3)
# Out:
#                                                 Area  \
# 0                               Geographic Area Name
# 1  Census Tract 101.01; San Francisco County; Cal...
# 2  Census Tract 101.02; San Francisco County; Cal...
#
#                                 DP05_0001E  \
# 0  Estimate!!SEX AND AGE!!Total population
# 1                                     2004
# 2                                     1795
#
#                                       DP05_0002E  \
# 0  Estimate!!SEX AND AGE!!Total population!!Male
# 1                                           1077
# 2                                            786
#
#                                         DP05_0003E  \
# 0  Estimate!!SEX AND AGE!!Total population!!Female
# 1                                              927
# 2                                             1009
#
#                                           DP05_0004E  \
# 0  Estimate!!SEX AND AGE!!Total population!!Sex r...
# ...

# %%
# rename columns
column_mapping = {}
for i, col in enumerate(df.columns):
    if i < len(df.iloc[0]):  # Make sure we don't go out of bounds
        column_mapping[col] = df.iloc[0, i]

df = df.rename(columns=column_mapping)
df.head(3)
# Out:
#                                 Geographic Area Name  \
# 0                               Geographic Area Name
# 1  Census Tract 101.01; San Francisco County; Cal...
# 2  Census Tract 101.02; San Francisco County; Cal...
#
#    Estimate!!SEX AND AGE!!Total population  \
# 0  Estimate!!SEX AND AGE!!Total population
# 1                                     2004
# 2                                     1795
#
#    Estimate!!SEX AND AGE!!Total population!!Male  \
# 0  Estimate!!SEX AND AGE!!Total population!!Male
# 1                                           1077
# 2                                            786
#
#    Estimate!!SEX AND AGE!!Total population!!Female  \
# 0  Estimate!!SEX AND AGE!!Total population!!Female
# 1                                              927
# 2                                             1009
#
#   Estimate!!SEX AND AGE!!Total population!!Sex ratio (males per 100 females)  \
# 0  Estimate!!SEX AND AGE!!Total population!!Sex r...
# ...

# %%
# remove the first row
df = df.drop(df.index[0])  
df = df.reset_index(drop=True)
df.head(3)
# Out:
#                                 Geographic Area Name  \
# 0  Census Tract 101.01; San Francisco County; Cal...
# 1  Census Tract 101.02; San Francisco County; Cal...
# 2  Census Tract 102.01; San Francisco County; Cal...
#
#   Estimate!!SEX AND AGE!!Total population  \
# 0                                    2004
# 1                                    1795
# 2                                    2608
#
#   Estimate!!SEX AND AGE!!Total population!!Male  \
# 0                                          1077
# 1                                           786
# 2                                          1325
#
#   Estimate!!SEX AND AGE!!Total population!!Female  \
# 0                                             927
# 1                                            1009
# 2                                            1283
#
#   Estimate!!SEX AND AGE!!Total population!!Sex ratio (males per 100 females)  \
# 0                                              116.2
# ...

# %%
# change Geographic Area Name to Area
df = df.rename(columns={'Geographic Area Name': 'Area'})

# %%
# print all column names
print(df.columns.tolist())
# Out:
# ['Area', 'Estimate!!SEX AND AGE!!Total population', 'Estimate!!SEX AND AGE!!Total population!!Male', 'Estimate!!SEX AND AGE!!Total population!!Female', 'Estimate!!SEX AND AGE!!Total population!!Sex ratio (males per 100 females)', 'Estimate!!SEX AND AGE!!Total population!!Under 5 years', 'Estimate!!SEX AND AGE!!Total population!!5 to 9 years', 'Estimate!!SEX AND AGE!!Total population!!10 to 14 years', 'Estimate!!SEX AND AGE!!Total population!!15 to 19 years', 'Estimate!!SEX AND AGE!!Total population!!20 to 24 years', 'Estimate!!SEX AND AGE!!Total population!!25 to 34 years', 'Estimate!!SEX AND AGE!!Total population!!35 to 44 years', 'Estimate!!SEX AND AGE!!Total population!!45 to 54 years', 'Estimate!!SEX AND AGE!!Total population!!55 to 59 years', 'Estimate!!SEX AND AGE!!Total population!!60 to 64 years', 'Estimate!!SEX AND AGE!!Total population!!65 to 74 years', 'Estimate!!SEX AND AGE!!Total population!!75 to 84 years', 'Estimate!!SEX AND AGE!!Total population!!85 years and over', '
# ...

# %%
# rename columns
df = df.rename(columns={
    'Estimate!!SEX AND AGE!!Total population!!Under 5 years': 'Under 5 years',
    'Estimate!!SEX AND AGE!!Total population!!5 to 9 years': '5 to 9 years',
    'Estimate!!SEX AND AGE!!Total population!!10 to 14 years': '10 to 14 years',
    'Estimate!!SEX AND AGE!!Total population!!15 to 19 years': '15 to 19 years',
    'Estimate!!SEX AND AGE!!Total population!!20 to 24 years': '20 to 24 years',
    'Estimate!!SEX AND AGE!!Total population!!25 to 34 years': '25 to 34 years',
    'Estimate!!SEX AND AGE!!Total population!!35 to 44 years': '35 to 44 years',
    'Estimate!!SEX AND AGE!!Total population!!45 to 54 years': '45 to 54 years',
    'Estimate!!SEX AND AGE!!Total population!!55 to 59 years': '55 to 59 years',
    'Estimate!!SEX AND AGE!!Total population!!60 to 64 years': '60 to 64 years',
    'Estimate!!SEX AND AGE!!Total population!!65 to 74 years': '65 to 74 years',
    'Estimate!!SEX AND AGE!!Total population!!75 to 84 years': '75 to 84 years',
    'Estimate!!SEX AND AGE!!Total population!!85 years and over': '85 years and over',
})
# only keep the columns we want 
df = df[['Area', 'Under 5 years', '5 to 9 years', '10 to 14 years', '15 to 19 years', 
         '20 to 24 years', '25 to 34 years', '35 to 44 years', 
         '45 to 54 years', '55 to 59 years', '60 to 64 years', 
         '65 to 74 years', '75 to 84 years', '85 years and over']]
df.head(3)
# Out:
#                                                 Area Under 5 years  \
# 0  Census Tract 101.01; San Francisco County; Cal...            62
# 1  Census Tract 101.02; San Francisco County; Cal...            45
# 2  Census Tract 102.01; San Francisco County; Cal...            56
#
#   5 to 9 years 10 to 14 years 15 to 19 years 20 to 24 years 25 to 34 years  \
# 0           21              0            133             46            441
# 1           46             79             97            109            244
# 2           48             57             68            149            886
#
#   35 to 44 years 45 to 54 years 55 to 59 years 60 to 64 years 65 to 74 years  \
# 0            519            230            156              0            182
# 1            401            124            142            138            160
# 2            307            289            113            198            247
#
#   75 to 84 years 85 years and over
# 0            119                95
# ...

# %%
# only keep numbers for the area column
df['Area'] = df['Area'].str.replace(r'.*Census Tract\s+', '', regex=True)  # remove everything before tract number
df['Area'] = df['Area'].str.replace(r';.*', '', regex=True)  # remove everything after semicolon
df['Area'] = df['Area'].str.strip()  # remove any extra whitespace
df
# Out:
#         Area Under 5 years 5 to 9 years 10 to 14 years 15 to 19 years  \
# 0     101.01            62           21              0            133
# 1     101.02            45           46             79             97
# 2     102.01            56           48             57             68
# 3     102.02            60           33              0             63
# 4        103           102           57              0             46
# ..       ...           ...          ...            ...            ...
# 239  9805.01             0            0              0              0
# 240     9806           138           70             99             26
# 241     9809            31            0             11              0
# 242     9901             0            0              0              0
# 243     9902             0            0              0              0
#
#     20 to 24 years 25 to 34 years 35 to 44 years 45 to 54 years  \
# ...

# %%
# combine age groups
df['5 to 19 years'] = df[['5 to 9 years', '10 to 14 years', '15 to 19 years']].apply(pd.to_numeric, errors='coerce').sum(axis=1)
df['20 to 34 years'] = df[['20 to 24 years', '25 to 34 years']].apply(pd.to_numeric, errors='coerce').sum(axis=1)
df['35 to 59 years'] = df[['35 to 44 years', '45 to 54 years', '55 to 59 years']].apply(pd.to_numeric, errors='coerce').sum(axis=1)
df['60 to 74 years'] = df[['60 to 64 years', '65 to 74 years']].apply(pd.to_numeric, errors='coerce').sum(axis=1)
df['75 plus'] = df[['75 to 84 years', '85 years and over']].apply(pd.to_numeric, errors='coerce').sum(axis=1)
df.head(3)
# only keep the columns we want
df = df[['Area', 'Under 5 years', '5 to 19 years', '20 to 34 years', 
         '35 to 59 years', '60 to 74 years', '75 plus']]
df.head(3)
# Out:
#      Area Under 5 years  5 to 19 years  20 to 34 years  35 to 59 years  \
# 0  101.01            62            154             487             905
# 1  101.02            45            222             353             667
# 2  102.01            56            173            1035             709
#
#    60 to 74 years  75 plus
# 0             182      214
# 1             298      210
# 2             445      190

# %%
# rename the columns to make them more readable
df = df.rename(columns={
    'Under 5 years': 'Under 5',
    '5 to 19 years': '5 to 19',
    '20 to 34 years': '20 to 34',
    '35 to 59 years': '35 to 59',
    '60 to 74 years': '60 to 74',
    '75 plus': '75 plus'
})
df.head(3)
# Out:
#      Area Under 5  5 to 19  20 to 34  35 to 59  60 to 74  75 plus
# 0  101.01      62      154       487       905       182      214
# 1  101.02      45      222       353       667       298      210
# 2  102.01      56      173      1035       709       445      190

# %%
# get total
df['Total'] = df[['Under 5', '5 to 19', '20 to 34', '35 to 59', '60 to 74', '75 plus']].apply(pd.to_numeric, errors='coerce').sum(axis=1)
df.head()
# Out:
#      Area Under 5  5 to 19  20 to 34  35 to 59  60 to 74  75 plus  Total
# 0  101.01      62      154       487       905       182      214   2004
# 1  101.02      45      222       353       667       298      210   1795
# 2  102.01      56      173      1035       709       445      190   2608
# 3  102.02      60       96       554       626       184      241   1761
# 4     103     102      103      1218      1189       866      313   3791

# %%
# convert numeric columns to proper data types
numeric_columns = ['Under 5', '5 to 19', '20 to 34', '35 to 59', '60 to 74', '75 plus', 'Total']
df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')

# create the dictionary in the format you want
result_dict = {
    'under 5': df.set_index('Area')['Under 5'].to_dict(),
    '5 to 19': df.set_index('Area')['5 to 19'].to_dict(), 
    '20 to 34': df.set_index('Area')['20 to 34'].to_dict(),
    '35 to 59': df.set_index('Area')['35 to 59'].to_dict(),
    '60 to 74': df.set_index('Area')['60 to 74'].to_dict(),
    '75 plus': df.set_index('Area')['60 to 74'].to_dict(),
    'total': df.set_index('Area')['Total'].to_dict()
}

# convert to JSON and save to file
import json

with open('/Users/agneslu/Desktop/neighborhood-data/data-new/age.json', 'w') as f:
    json.dump(result_dict, f, indent=2)

print("JSON file saved as 'age.json'")
# Out:
# JSON file saved as 'age.json'
